# %%
### some error came out if apply textatistic package directly,
### so add constaints on textatistic package: if word length(characters) in word_array less than 30, then do "hyphen"
### The result of flesch_score will be used in prediction

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import numpy as np
import textatistic as ts

df=pd.read_csv("C:/Users/USER/Desktop/data.csv", header=0)

df['sent_count']=df['descripton'].apply(ts.sent_count)
df['word_count']=df['descripton'].apply(ts.word_count)
#print(df['flesch_score'])
df.to_csv("C:/Users/USER/Desktop/testReadData1.csv", header=True, index=False)

# %%
### trial and error part
### take a look of word_array (print max character in word_array)
### find that some long words come from URL which we don't want them.
### this cause an error when applying hyphen function in package.
import pandas as pd
import numpy as np
import textatistic as ts

df=pd.read_csv("C:/Users/USER/Desktop/testReadData1.csv", header=0)

df['word_array']=df['descripton'].apply(ts.word_array)
data_list=df['word_array'].values.tolist()

for word_arr in data_list:
    print(max(word_arr, key=len))
# Out:
# articulates
# misunderstandings
# disclosing
# Illustration
# Developmental
# etceteraStyle
# dominatingWinning
# entertainment
# miscellaneous
# Kickstarterites
# understandable
# PartnersInCrimeAJ
# httpjillianlomanblogspotcom
# httpalmostsuperorgchapteronepdf
# httpzartofwellnesscom
# Massachusetts
# importantly
# hospitalized
# collections
# importantly
# character
# Cinematographer
# recognized
# httpchangethiscommanifestoshow2706UnwealthyHabits
# transforming
# kickstarter
# appropriately
# hallucinations
# httptracyblanchardwanderlustwordpresscom
# screenprinting
# matsallehmanker
# blogsnewsletters
# illustrations
# httpswwwfacebookcomNathanDoverspikeIllustration
# VillainStatus
# appreciated
# httpwwwrkfinchdesignblogspotcom
# interviewing
# transitional
# wwwcamdenlockclothingcouk
# aesthetically
# opportunity
# legalization
# illustrator
# resistant
# Kickstarter
# httpfbystrovblogspotru
# reconstruction
# infrastructure
# inspiration
# celebrities
# ...

# %%
import pandas as pd
import numpy as np
import textatistic as ts

df=pd.read_csv("C:/Users/USER/Desktop/testReadData1.csv", header=0)

# apply Flesch score readability
# skip sent_count=0 and word_count=0 to prevent traceback
df['flesch_score']=df.loc[(df.sent_count >0) & (df.word_count >0)]['descripton'].apply(ts.flesch_score)

df.to_csv("C:/Users/USER/Desktop/testReadData2.csv", header=True, index=False)

# %%
import pandas as pd
import numpy as np

df=pd.read_csv("C:/Users/USER/Desktop/testReadData2.csv", header=0)

df.head()
df.shape #(52651, 51)
# Out:
#    Unnamed: 0  backers_count  \
# 0           3              1
# 1          21              1
# 2          27              0
# 3          28              0
# 4          29              0
#
#                                                blurb  \
# 0  A forum for those passionate about travel and ...
# 1  I aim to travel the world, recording my experi...
# 2  Creating a fan made Naruto in which Sasuke bec...
# 3  Sketches of London are modern illustrations of...
# 4  The Urban Artist Developmental Society is a gr...
#
#                                             category  \
# 0  {"id":13,"name":"Journalism","slug":"journalis...
# 1  {"id":13,"name":"Journalism","slug":"journalis...
# 2  {"id":22,"name":"Illustration","slug":"art/ill...
# 3  {"id":22,"name":"Illustration","slug":"art/ill...
# 4  {"id":22,"name":"Illustration","slug":"art/ill...
#
#    converted_pledged_amount country  created_at  \
# 0                         1      US  1424637235
# ...

# %%
# output only readability column
df['flesch_score'].to_csv("C:/Users/USER/Desktop/readScore.csv", header=True, index=False)

# %%
# check the shape of readability cloumn
import pandas as pd
import numpy as np

df=pd.read_csv("C:/Users/USER/Desktop/readScore.csv", header=0)
df.shape #(52651, 1)
# Out:
# (52651, 1)
